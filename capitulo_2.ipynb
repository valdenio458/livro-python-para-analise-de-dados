# %%
b = [1,2,3]

# %%
b?

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.random.randn(50).cumsum())

# %%
a = [1, 2, 3]

# %%
b = a

# %%
a.append(4)

# %%
b
# Out:
# [1, 2, 3, 4]

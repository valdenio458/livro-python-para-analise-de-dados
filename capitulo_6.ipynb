# %% [markdown]
# <a href="https://colab.research.google.com/github/valdenio458/livro-python-para-analise-de-dados/blob/main/capitulo_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('examples/ex1.csv')

# %%
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
result = pd.read_csv('examples/ex5.csv')

# %%
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
pd.isnull(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %% [markdown]
# Lendo arquivos-texto em partes

# %%
pd.options.display.max_rows = 10

# %%
result = pd.read_csv('examples/ex6.csv')

# %%
result
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
#Para ler uma quantidade pequena de linhas use 'nrows'
pd.read_csv('examples/ex6.csv', nrows=5)
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %% [markdown]
# Interagindo com APIs web

# %%
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61559',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61559/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61559/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61559/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61559',
#   'id': 3118769967,
#   'node_id': 'I_kwDOAA0YD8655Kcv',
#   'number': 61559,
#   'title': 'Pandas DataFrame.query Code Injection (Unpatched)',
#   'user': {'login': 'clyormz',
#    'id': 46636968,
#    'node_id': 'MDQ6VXNlcjQ2NjM2OTY4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46636968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/clyormz',
#    'html_url': 'https://github.com/clyormz',
#    'followers_url': 'https://api.github.com/users/clyormz/followers',
#    'following_url': 'https://api.github.com/users/clyormz/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/clyormz/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/clyormz/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/clyormz/subscriptions',
#    'organizations_url': 'https://api.github.com/users/clyormz/orgs',
#    'repos_url': 'https://api.github.com/users/clyormz/repos',
#    'events_url': 'https://api.github.com/users/clyormz/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/clyormz/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-06-04T18:45:13Z',
#   'updated_at': '2025-06-04T18:45:13Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'body': 'Python pandas version 2.2.3 has a vulnerability on Pandas DataFrame.query \n\nIn order to fix the function query on DataFrame python class what are the elements to review to resolve the vulnerability CVE-2024-9880.\n\nRegards',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61559/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61559/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61558',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61558/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61558/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61558/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61558',
#   'id': 3118724429,
#   'node_id': 'PR_kwDOAA0YD86ZEnFO',
#   'number': 61558,
#   'title': 'Backport PR #61519: BUILD: Bump Cython to 3.1',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 129350,
#     'node_id': 'MDU6TGFiZWwxMjkzNTA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Build',
#     'name': 'Build',
#     'color': '75507B',
#     'default': False,
#     'description': 'Library building on various platforms'},
#    {'id': 527603109,
#     'node_id': 'MDU6TGFiZWw1Mjc2MDMxMDk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dependencies',
#     'name': 'Dependencies',
#     'color': 'd93f0b',
#     'default': False,
#     'description': 'Required and optional dependencies'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/119',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/119',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/119/labels',
#    'id': 11466880,
#    'node_id': 'MI_kwDOAA0YD84ArviA',
#    'number': 119,
#    'title': '2.3',
#    'description': 'on-merge: backport to 2.3.x',
#    'creator': {'login': 'jorisvandenbossche',
#     'id': 1020496,
#     'node_id': 'MDQ6VXNlcjEwMjA0OTY=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/1020496?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jorisvandenbossche',
#     'html_url': 'https://github.com/jorisvandenbossche',
#     'followers_url': 'https://api.github.com/users/jorisvandenbossche/followers',
#     'following_url': 'https://api.github.com/users/jorisvandenbossche/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jorisvandenbossche/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jorisvandenbossche/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jorisvandenbossche/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jorisvandenbossche/orgs',
#     'repos_url': 'https://api.github.com/users/jorisvandenbossche/repos',
#     'events_url': 'https://api.github.com/users/jorisvandenbossche/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jorisvandenbossche/received_events',
#     'type': 'User',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'open_issues': 2,
#    'closed_issues': 341,
#    'state': 'open',
#    'created_at': '2024-08-20T19:39:44Z',
#    'updated_at': '2025-06-04T18:28:57Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2025-06-04T18:28:57Z',
#   'updated_at': '2025-06-04T18:28:57Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61558',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61558',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61558.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61558.patch',
#    'merged_at': None},
#   'body': 'https://github.com/pandas-dev/pandas/pull/61519',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61558/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61558/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61557',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61557/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61557/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61557/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61557',
#   'id': 3118522709,
#   'node_id': 'I_kwDOAA0YD8654OFV',
#   'number': 61557,
#   'title': 'BUG: regex match in compliance tests no longer match pytest expected inputs',
#   'user': {'login': 'chalmerlowe',
#    'id': 7291104,
#    'node_id': 'MDQ6VXNlcjcyOTExMDQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7291104?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chalmerlowe',
#    'html_url': 'https://github.com/chalmerlowe',
#    'followers_url': 'https://api.github.com/users/chalmerlowe/followers',
#    'following_url': 'https://api.github.com/users/chalmerlowe/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/chalmerlowe/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/chalmerlowe/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/chalmerlowe/subscriptions',
#    'organizations_url': 'https://api.github.com/users/chalmerlowe/orgs',
#    'repos_url': 'https://api.github.com/users/chalmerlowe/repos',
#    'events_url': 'https://api.github.com/users/chalmerlowe/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/chalmerlowe/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-06-04T17:11:35Z',
#   'updated_at': '2025-06-04T17:11:35Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'type': None,
#   'active_lock_reason': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'body': '### Pandas version checks\n\n- [x] I have checked that this issue has not already been reported.\n\n- [x] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nN/A\n```\n\n### Issue Description\n\nWhen I run compliance tests in python-db-dtype-pandas (a support file used by python-bigquery) I am getting multiple warnings (which cause test failures) due to a recent update in how pytest handles regex matches.\n\nIn pandas release 2.2.3 there is a snippet of code:\n```\ndef test_take_pandas_style_negative_raises(self, data, na_value):\n    with pytest.raises(ValueError, match=""):\n```\n\nPytest returns this Warning:\n\n```\npytest.PytestWarning: matching against an empty string will *always* pass. If you want to check for an empty message you need to pass \'^$\'. If you don\'t want to match you should pass `None` or leave out the parameter.\n```\n\nThis warning shows up in association with each of these pandas tests (it may occur with other tests, but these are the only ones that my tests revealed.):\n```\nFAILED ...::TestGetitem::test_take_pandas_style_negative_raises\nFAILED ...::TestMethods::test_argmax_argmin_no_skipna_notimplemented\nFAILED ...::TestSetitem::test_setitem_invalid\nFAILED ...::TestJSONArrayGetitem::test_take_pandas_style_negative_raises\nFAILED ...::TestJSONArrayMethods::test_argmax_argmin_no_skipna_notimplemented\nFAILED ...::TestJSONArraySetitem::test_setitem_invalid\n```\n\n\n### Expected Behavior\n\nN/A\n\n### Installed Versions\n\nN/A',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61557/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61557/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61555',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61555/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61555/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61555/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61555',
#   'id': 3117071656,
#   'node_id': 'PR_kwDOAA0YD86Y-985',
#   'number': 61555,
#   'title': 'Upgrade Python version for development environment',
#   'user': {'login': 'datapythonista',
#    'id': 10058240,
#    'node_id': 'MDQ6VXNlcjEwMDU4MjQw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10058240?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/datapythonista',
#    'html_url': 'https://github.com/datapythonista',
#    'followers_url': 'https://api.github.com/users/datapythonista/followers',
#    'following_url': 'https://api.github.com/users/datapythonista/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/datapythonista/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/datapythonista/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/datapythonista/subscriptions',
#    'organizations_url': 'https://api.github.com/users/datapythonista/orgs',
#    'repos_url': 'https://api.github.com/users/datapythonista/repos',
#    'events_url': 'https://api.github.com/users/datapythonista/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/datapythonista/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 527603109,
#     'node_id': 'MDU6TGFiZWw1Mjc2MDMxMDk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dependencies',
#     'name': 'Dependencies',
#     'color': 'd93f0b',
#     'default': False,
#     'description': 'Required and optional dependencies'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2025-06-04T09:04:21Z',
#   'updated_at': '2025-06-04T16:33:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61555',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61555',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61555.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61555.patch',
#    'merged_at': None},
#   'body': "I guess the only reason we require Python 3.10 for the development environments and run the docs is because it wasn't updated for a long time. Not sure if it'd be better to unpin, which I assume would get us the latest version of Python. Happy to do that here too.",
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61555/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61555/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61554',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61554/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61554/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61554/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61554',
#   'id': 3117048901,
#   'node_id': 'I_kwDOAA0YD865ymRF',
#   'number': 61554,
#   'title': 'BUG: duplicated() raises error with singlton set as subset',
#   'user': {'login': 'camold',
#    'id': 2109454,
#    'node_id': 'MDQ6VXNlcjIxMDk0NTQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2109454?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/camold',
#    'html_url': 'https://github.com/camold',
#    'followers_url': 'https://api.github.com/users/camold/followers',
#    'following_url': 'https://api.github.com/users/camold/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/camold/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/camold/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/camold/subscriptions',
#    'organizations_url': 'https://api.github.com/users/camold/orgs',
#    'repos_url': 'https://api.github.com/users/camold/repos',
#    'events_url': 'https://api.github.com/users/camold/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/camold/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-06-04T08:57:11Z',
#   'updated_at': '2025-06-04T08:57:11Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'body': '### Pandas version checks\n\n- [x] I have checked that this issue has not already been reported.\n\n- [x] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\ndf = pd.DataFrame([{"a": "foo", "b": "bar"}])\ndf.duplicated(subset={"a"}) # raises error\ndf.duplicated(subset=["a"]) # works\ndf.duplicated(subset=("a",)) # works\ndf.duplicates(subset={"a","b"}) # works\n```\n\n### Issue Description\n\nProviding a singleton set to the subset parameter raises an error.\n\n### Expected Behavior\n\nShould work normally without having to convert the input to list or tuple.\n\n### Installed Versions\n\n<details>\n\nINSTALLED VERSIONS\n------------------\ncommit                : 0691c5cf90477d3503834d983f69350f250a6ff7\npython                : 3.12.3\npython-bits           : 64\nOS                    : Linux\nOS-release            : 6.11.0-26-generic\nVersion               : #26~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Thu Apr 17 19:20:47 UTC 2\nmachine               : x86_64\nprocessor             : x86_64\nbyteorder             : little\nLC_ALL                : None\nLANG                  : de_DE.UTF-8\nLOCALE                : de_DE.UTF-8\n\npandas                : 2.2.3\nnumpy                 : 2.2.0\npytz                  : 2024.2\ndateutil              : 2.9.0.post0\npip                   : 24.0\nCython                : None\nsphinx                : None\nIPython               : 8.29.0\nadbc-driver-postgresql: None\nadbc-driver-sqlite    : None\nbs4                   : 4.12.3\nblosc                 : None\nbottleneck            : None\ndataframe-api-compat  : None\nfastparquet           : None\nfsspec                : None\nhtml5lib              : None\nhypothesis            : None\ngcsfs                 : None\njinja2                : 3.1.4\nlxml.etree            : 5.3.0\nmatplotlib            : 3.9.2\nnumba                 : None\nnumexpr               : None\nodfpy                 : None\nopenpyxl              : 3.1.5\npandas_gbq            : None\npsycopg2              : None\npymysql               : None\npyarrow               : None\npyreadstat            : None\npytest                : 8.3.3\npython-calamine       : None\npyxlsb                : None\ns3fs                  : None\nscipy                 : None\nsqlalchemy            : 2.0.36\ntables                : None\ntabulate              : None\nxarray                : None\nxlrd                  : None\nxlsxwriter            : None\nzstandard             : None\ntzdata                : 2024.2\nqtpy                  : None\npyqt5                 : None\n\n\n</details>\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61554/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61554/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61552',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61552/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61552/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61552/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61552',
#   'id': 3116474516,
#   'node_id': 'PR_kwDOAA0YD86Y9COH',
#   'number': 61552,
#   'title': "DOC: Add note on inference behavior of apply with result_type='expand'",
#   'user': {'login': 'pinkgradient',
#    'id': 101425679,
#    'node_id': 'U_kgDOBguiDw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101425679?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pinkgradient',
#    'html_url': 'https://github.com/pinkgradient',
#    'followers_url': 'https://api.github.com/users/pinkgradient/followers',
#    'following_url': 'https://api.github.com/users/pinkgradient/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pinkgradient/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pinkgradient/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pinkgradient/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pinkgradient/orgs',
#    'repos_url': 'https://api.github.com/users/pinkgradient/repos',
#    'events_url': 'https://api.github.com/users/pinkgradient/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pinkgradient/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform, Map'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2025-06-04T05:20:11Z',
#   'updated_at': '2025-06-04T11:01:04Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61552',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61552',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61552.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61552.patch',
#    'merged_at': None},
#   'body': "Closes #61057\r\n\r\n- This PR adds a docstring note about the inference behavior of apply with result_type='expand' when function returns NaN-like values, as discussed in issue #61057.\r\n- Added docstring to distinguish behavior for 'apply' method.",
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61552/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61552/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61551',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61551/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61551/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61551/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61551',
#   'id': 3116401342,
#   'node_id': 'PR_kwDOAA0YD86Y80iP',
#   'number': 61551,
#   'title': 'Parallelize test_sql.py - Issue #60378',
#   'user': {'login': 'dShcherbakov1',
#    'id': 119084461,
#    'node_id': 'U_kgDOBxkVrQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/119084461?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dShcherbakov1',
#    'html_url': 'https://github.com/dShcherbakov1',
#    'followers_url': 'https://api.github.com/users/dShcherbakov1/followers',
#    'following_url': 'https://api.github.com/users/dShcherbakov1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dShcherbakov1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dShcherbakov1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dShcherbakov1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dShcherbakov1/orgs',
#    'repos_url': 'https://api.github.com/users/dShcherbakov1/repos',
#    'events_url': 'https://api.github.com/users/dShcherbakov1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dShcherbakov1/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-06-04T04:47:40Z',
#   'updated_at': '2025-06-04T16:37:06Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61551',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61551',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61551.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61551.patch',
#    'merged_at': None},
#   'body': '- [x] closes #60378\r\n- [x] Added per-worker PostgreSQL and MySQL DBs.\r\n- [x] Configured PostgreSQL and MySQL DB cleanup, setup, and teardown by using Pytest fixtures and objects.\r\n- [x] Per-worker DBs initialized in a round-robin order to avoid potentially overtaxing SQL Engine connections. \r\n- [x] Initialization of per-worker DBs is easily expandable to other potential SQL engines.\r\n- [x] Ensured test_sql still runs fine single threaded.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61551/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61551/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61550',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61550/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61550/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61550/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61550',
#   'id': 3116382404,
#   'node_id': 'PR_kwDOAA0YD86Y8ynF',
#   'number': 61550,
#   'title': 'DOC: Remove and Update out of date Docker Image issue with  #61511',
#   'user': {'login': 'jacksnnn',
#    'id': 175151559,
#    'node_id': 'U_kgDOCnCZxw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/175151559?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jacksnnn',
#    'html_url': 'https://github.com/jacksnnn',
#    'followers_url': 'https://api.github.com/users/jacksnnn/followers',
#    'following_url': 'https://api.github.com/users/jacksnnn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jacksnnn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jacksnnn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jacksnnn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jacksnnn/orgs',
#    'repos_url': 'https://api.github.com/users/jacksnnn/repos',
#    'events_url': 'https://api.github.com/users/jacksnnn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jacksnnn/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2025-06-04T04:40:39Z',
#   'updated_at': '2025-06-04T12:49:55Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61550',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61550',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61550.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61550.patch',
#    'merged_at': None},
#   'body': '- [ ] Addresses & closes [DOC: Docker image provided on "Debugging C extensions" is out of date #61511](https://github.com/pandas-dev/pandas/issues/61511)  \r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61550/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61550/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61546',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61546/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61546/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61546/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61546',
#   'id': 3115813278,
#   'node_id': 'PR_kwDOAA0YD86Y69PY',
#   'number': 61546,
#   'title': 'ENH: Adding DataFrame plotting benchmarks for large datasets',
#   'user': {'login': 'shadnikn',
#    'id': 147014887,
#    'node_id': 'U_kgDOCMNE5w',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/147014887?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shadnikn',
#    'html_url': 'https://github.com/shadnikn',
#    'followers_url': 'https://api.github.com/users/shadnikn/followers',
#    'following_url': 'https://api.github.com/users/shadnikn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/shadnikn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/shadnikn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/shadnikn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/shadnikn/orgs',
#    'repos_url': 'https://api.github.com/users/shadnikn/repos',
#    'events_url': 'https://api.github.com/users/shadnikn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/shadnikn/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 732775912,
#     'node_id': 'MDU6TGFiZWw3MzI3NzU5MTI=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Benchmark',
#     'name': 'Benchmark',
#     'color': 'ae68cc',
#     'default': False,
#     'description': 'Performance (ASV) benchmarks'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2025-06-04T00:21:17Z',
#   'updated_at': '2025-06-04T16:40:20Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61546',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61546',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61546.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61546.patch',
#    'merged_at': None},
#   'body': "- [ ] related to #61532  - Adding in performance benchmarks for DataFrame plotting with large datasets.\r\n- [ ] Description: Added 'DataFramePlottingLarge' benchmark class to track performance issues related to bottlenecks in #61398 and #61532. Tests multiple DataFrame sizes with/w/o DatetimeIndex & provides a baseline single-column comparison.\r\n- [ ] Intended to cover:\r\n          - DataFrame sizes: (1000,10) to (10000,10)\r\n          - DatetimeIndex vs. regular index comparison\r\n          - Multi-column vs. single-column plotting.\r\n",
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61546/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61546/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61543',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61543/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61543/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61543/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61543',
#   'id': 3115248818,
#   'node_id': 'PR_kwDOAA0YD86Y5Ety',
#   'number': 61543,
#   'title': 'DOC: Fix docs for BusinessDay constructor #52431',
#   'user': {'login': 'camacluc',
#    'id': 114314487,
#    'node_id': 'U_kgDOBtBM9w',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/114314487?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/camacluc',
#    'html_url': 'https://github.com/camacluc',
#    'followers_url': 'https://api.github.com/users/camacluc/followers',
#    'following_url': 'https://api.github.com/users/camacluc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/camacluc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/camacluc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/camacluc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/camacluc/orgs',
#    'repos_url': 'https://api.github.com/users/camacluc/repos',
#    'events_url': 'https://api.github.com/users/camacluc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/camacluc/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-06-03T19:50:59Z',
#   'updated_at': '2025-06-03T19:51:05Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61543',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61543',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61543.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61543.patch',
#    'merged_at': None},
#   'body': 'fix constructor for offset BusinessDay\r\n\r\n- [ ] addresses #52431 \r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61543/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61543/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61542',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61542/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61542/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61542/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61542',
#   'id': 3114631618,
#   'node_id': 'PR_kwDOAA0YD86Y2-S4',
#   'number': 61542,
#   'title': 'CI: Debug slow environment solve times',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2025-06-03T16:19:34Z',
#   'updated_at': '2025-06-04T09:05:48Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61542',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61542',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61542.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61542.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61542/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61542/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61541',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61541/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61541/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61541/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61541',
#   'id': 3114329620,
#   'node_id': 'PR_kwDOAA0YD86Y1-gs',
#   'number': 61541,
#   'title': 'Fix Index.equals between object and string',
#   'user': {'login': 'sanggon6107',
#    'id': 68040183,
#    'node_id': 'MDQ6VXNlcjY4MDQwMTgz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68040183?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sanggon6107',
#    'html_url': 'https://github.com/sanggon6107',
#    'followers_url': 'https://api.github.com/users/sanggon6107/followers',
#    'following_url': 'https://api.github.com/users/sanggon6107/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sanggon6107/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sanggon6107/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sanggon6107/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sanggon6107/orgs',
#    'repos_url': 'https://api.github.com/users/sanggon6107/repos',
#    'events_url': 'https://api.github.com/users/sanggon6107/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sanggon6107/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-06-03T14:54:11Z',
#   'updated_at': '2025-06-04T13:38:41Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/61541',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/61541',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/61541.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/61541.patch',
#    'merged_at': None},
#   'body': '- [X] closes #61099 \r\n- [X] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [X] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\n## Description of the code change on `Index.equals`\r\n\r\nOn the main branch, `Index.equals` casts `self` to `object` only when `self.dtype.na_value` is `np.nan`. The comparison actually succeeds when `self.dtype.na_value` is `np.nan` as below.\r\n```python\r\n>>> import pandas as pd\r\n>>> import numpy as np\r\n\r\n>>> s1 = pd.Series([1, 2, 3], index=[\'a\', \'b\', \'c\'])\r\n>>> s2 = pd.Series([4, 5, 6], index=[\'a\', \'b\', \'c\'])\r\n>>> s2.index = s2.index.astype(pd.StringDtype(storage="pyarrow", na_value=np.nan))\r\n\r\n>>> print(s1 < s2)\r\na    True\r\nb    True\r\nc    True\r\ndtype: bool\r\n```\r\nHowever, since doc stated that `dtype` is not compared, `self` should be casted regardless of `self.dtype.na_value` so that `self` could be compared with other dtypes as desired.\r\n\r\n\r\n## Description of the code change on `test_mixed_col_index_dtype`\r\n\r\n`using_infer_string` has been removed since I think that `result` should be `string` regardless of `using_infer_string`. This is becaus of the code change made on `Index.equals` - since `Index.equals` consider `df1.columns` is equal to `df2.colums`, `Index.intersection` returns `self`(which is `string`). You could see the result becomes `object`(which is the dtype of `df2`) in case of `result = df2 + df1`. On the main branch, on the other hand, `Index.intersection` returns `object` because `Index.equals` returns `False`, and then both `self` and `other` are cast to `object` by `_find_common_type_compat`. (see `L3287` at pandas/core/indexes/base.py)\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/25e64629ec317fba2fc1c2834b20362fa6c1fd89/pandas/core/indexes/base.py#L3286-L3290\r\n\r\n\r\n* I created this pull request since @MayurKishorKumar doesn\'t seem to work on this issue anymore, but please let me know if there is going to be further actions on the previous PR and I am supposed to close this one.',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61541/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61541/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61540',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61540/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61540/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61540/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/61540',
#   'id': 3113693938,
#   'node_id': 'PR_kwDOAA0YD86Yzzcs',
#   'number': 61540,
#   'title': 'ENH pandas-dev#60693: shift operations for Series and DataFrames',
#   'user': {'login': 'David-msggc',
#    'id': 95498196,
#    'node_id': 'U_kgDOBbEv1A',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95498196?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/David-msggc',
#    'html_url': 'https://github.com/David-msggc',
#    'followers_url': 'https://api.github.com/users/David-msggc/followers',
# ...
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 57296398,
#     'node_id': 'MDU6TGFiZWw1NzI5NjM5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Algos',
#     'name': 'Algos',
#     'color': 'eb6420',
#     'default': False,
#     'description': 'Non-arithmetic algos: value_counts, factorize, sorting, isin, clip, shift, diff'},
#    {'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'},
#    {'id': 219960758,
#     'node_id': 'MDU6TGFiZWwyMTk5NjA3NTg=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Discussion',
#     'name': 'Needs Discussion',
#     'color': '207de5',
#     'default': False,
#     'description': 'Requires discussion from core team before further action'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 10,
#   'created_at': '2025-05-29T22:14:58Z',
#   'updated_at': '2025-06-04T18:10:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'body': '### Pandas version checks\n\n- [x] I have checked that this issue has not already been reported.\n\n- [x] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [x] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\n\ndata = {\'w\': [100, 1, 1]}\ndf = pd.DataFrame(data)\n\ndf.sample(n=2, weights=df.w, replace=False)\n```\n\n### Issue Description\n\nIn order for PPS sampling without replacement to be feasible, the selection probabilities must be less than 1, i.e.\n\n$ \\frac{n \\cdot w_i}{\\sum w_i}< 1$\n\nwhere w is the weight and n is the total number of units to be sampled. This is often not the case if you are selecting a decent proportion of all units and there is wide variance in unit size. For example, suppose you want to select 2 units with PPS without replacement from a sampling frame of 3 units with sizes 100, 1, and 1. There is no way to make the probability of selection of the first unit 100x the probability of selection of the other two units (since the max prob for the first unit is 1 and at least one of the other units must have prob >= .5).\n\nUnfortunately, pandas df.sampling function doesn\'t throw an error in this case. \n\n### Expected Behavior\n\nThe code above should throw some sort of error like "Some unit probabilities are larger than 1 and thus PPS sampling without replacement cannot be performed"\n\n### Installed Versions\n\n<details>\n\nReplace this line with the output of pd.show_versions()\n\n</details>\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61516/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61516/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61515',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61515/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61515/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61515/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61515',
#   'id': 3100485724,
#   'node_id': 'I_kwDOAA0YD864zahc',
#   'number': 61515,
#   'title': 'ENH: Ability to name columns/index levels when using `.str.split(..., expand=True)` on `Index`/`Series`',
#   'user': {'login': 'nachomaiz',
#    'id': 24781490,
#    'node_id': 'MDQ6VXNlcjI0NzgxNDkw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24781490?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nachomaiz',
#    'html_url': 'https://github.com/nachomaiz',
#    'followers_url': 'https://api.github.com/users/nachomaiz/followers',
#    'following_url': 'https://api.github.com/users/nachomaiz/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/nachomaiz/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/nachomaiz/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/nachomaiz/subscriptions',
#    'organizations_url': 'https://api.github.com/users/nachomaiz/orgs',
#    'repos_url': 'https://api.github.com/users/nachomaiz/repos',
#    'events_url': 'https://api.github.com/users/nachomaiz/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/nachomaiz/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2025-05-29T14:11:53Z',
#   'updated_at': '2025-05-30T09:23:05Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'body': '### Feature Type\n\n- [x] Adding new functionality to pandas\n\n- [x] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nWhen using `.str.split(..., expand=True)`:\n- On a `Series` the resulting dataframe columns are labeled with numbers by default\n- On an `Index` the resulting levels are not labeled\n\nIt would be great if we could specify the names that the new columns or levels will take once the split is performed.\n\n### Feature Description\n\nI think it would be helpful if the method had a `names` parameter that would at a minimum accept a sequence of labels for the newly created columns/levels, similarly to how `MultiIndex` is initialized.\n\nIt could work like so:\n\n```py\n>>> index = pd.Index(["a_b"])\n>>> index.str.split("_", expand=True, names=["A", "B"])\nMultiIndex([(\'a\', \'b\')], names=["A", "B"], length=1)\n>>> series = pd.Series(["a_b"])\n>>> series.str.split("_", expand=True, names=["A", "B"])\n|   | A | B |\n|---|---|---|\n| 0 | a | b |\n```\nThe length of the `names` sequence should match the number of expanded columns/levels, otherwise it should throw a `ValueError`.\n\n### Alternative Solutions\n\nFor `Index`, this works almost exactly the same:\n```py\n>>> index.str.split("_", expand=True).rename(["A", "B"])\n```\nSo I think it\'s not as impactful for `Index`.\n\nBut for `Series`, this becomes more cumbersome, and the need to specify the renaming via a dictionary makes it feel disjointed vs the easier index renaming and `MultiIndex` instantiation:\n```py\n>>> series.str.split("_", expand=True).rename(columns={0: "A", 1: "B"})\n```\n\nSo my proposal would provide a similar interface for using the `split` method of the `str` accessor across pandas sequences.\n\n### Additional Context\n\n_No response_',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61515/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61515/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61513',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61513/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61513/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61513/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61513',
#   'id': 3099904854,
#   'node_id': 'I_kwDOAA0YD864xMtW',
#   'number': 61513,
#   'title': 'ENH: Adding pd.from_pydantic',
#   'user': {'login': 'JavierLopezT',
#    'id': 11339132,
#    'node_id': 'MDQ6VXNlcjExMzM5MTMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11339132?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JavierLopezT',
#    'html_url': 'https://github.com/JavierLopezT',
#    'followers_url': 'https://api.github.com/users/JavierLopezT/followers',
#    'following_url': 'https://api.github.com/users/JavierLopezT/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/JavierLopezT/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/JavierLopezT/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/JavierLopezT/subscriptions',
#    'organizations_url': 'https://api.github.com/users/JavierLopezT/orgs',
#    'repos_url': 'https://api.github.com/users/JavierLopezT/repos',
#    'events_url': 'https://api.github.com/users/JavierLopezT/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/JavierLopezT/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2025-05-29T10:34:29Z',
#   'updated_at': '2025-05-29T10:34:29Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'type': None,
#   'active_lock_reason': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'body': '### Feature Type\n\n- [x] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nThere are a few methods to get a pandas DataFrame from a Pydantic model, but it will be just easier and more readable to not have any intermediate step. \n\n### Feature Description\n\nIdeally, I could do something like:\n\nfrom pydantic import BaseModel\nclass Item(BaseModel):\n    item_category: str\n    item_name: str\n    purchase_price: float\n    suggested_retail_price: float\n    item_number: int\n    margin: float\n    note: Optional[str] = None\n\nresponse = : list[Item]\ndf = pd.from_pydantic(response)\n\nAnd I will get a pandas df with columns `item_category, item_name, purchase_price, suggested_retail_price, item_number, margin, note` and on each row, one element of the list in response\n\n### Alternative Solutions\n\nhttps://stackoverflow.com/questions/61814887/how-to-convert-a-list-of-pydantic-basemodels-to-pandas-dataframe\n\n### Additional Context\n\n_No response_',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61513/reactions',
#    'total_count': 1,
#    '+1': 1,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61513/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61511',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61511/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61511/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61511/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/61511',
#   'id': 3098321760,
#   'node_id': 'I_kwDOAA0YD864rKNg',
#   'number': 61511,
#   'title': 'DOC: Docker image provided on "Debugging C extensions" is out of date',
#   'user': {'login': 'eicchen',
#    'id': 63069720,
#    'node_id': 'MDQ6VXNlcjYzMDY5NzIw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63069720?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eicchen',
#    'html_url': 'https://github.com/eicchen',
#    'followers_url': 'https://api.github.com/users/eicchen/followers',
#    'following_url': 'https://api.github.com/users/eicchen/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/eicchen/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/eicchen/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/eicchen/subscriptions',
#    'organizations_url': 'https://api.github.com/users/eicchen/orgs',
#    'repos_url': 'https://api.github.com/users/eicchen/repos',
#    'events_url': 'https://api.github.com/users/eicchen/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/eicchen/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 6,
#   'created_at': '2025-05-28T19:12:36Z',
#   'updated_at': '2025-06-02T22:26:24Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'type': None,
#   'active_lock_reason': None,
#   'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#   'body': '### Pandas version checks\n\n- [x] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/development/debugging_extensions.html\n\n### Documentation problem\n\nDocker image provided on linked page includes out of date pip and meson which causes build errors without manual updates to the installed docker image.\n\nAdditionally, when brought up in the bi-weekly meeting, it was mentioned that the preferred method is to locally install cygdb so the documentation should be updated to reflect this knowledge.\n\n### Suggested fix for documentation\n\nEither update or remove provided docker image and add that local installations are preferred.\n',
#   'closed_by': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61511/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/61511/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
data[20]['title']
# Out:
# 'raise TypeError when function returns object-like results'

# %%
# Passando 'data' para DataFrame e extraindo os campos de interesse
issues = pd.DataFrame(data, columns=['title', 'labels', 'state'])

# %%
issues
# Out:
#                                                 title  \
# 0   Pandas DataFrame.query Code Injection (Unpatched)
# 1       Backport PR #61519: BUILD: Bump Cython to 3.1
# 2   BUG: regex match in compliance tests no longer...
# 3   Upgrade Python version for development environ...
# 4   BUG: duplicated() raises error with singlton s...
# ..                                                ...
# 25  Misleading error message when PyTables is not ...
# 26  BUG: DataFrame.sample weights not required to ...
# 27  ENH: Ability to name columns/index levels when...
# 28                       ENH: Adding pd.from_pydantic
# 29  DOC: Docker image provided on "Debugging C ext...
#
#                                                labels state
# 0                                                  []  open
# 1   [{'id': 129350, 'node_id': 'MDU6TGFiZWwxMjkzNT...  open
# 2   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 3   [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 4   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# ..                                                ...   ...
# 25  [{'id': 42670965, 'node_id': 'MDU6TGFiZWw0MjY3...  open
# 26  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 27  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 28  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 29  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
#
# [30 rows x 3 columns]

# %% [markdown]
# Testando API de Pokemons

# %%
import requests

# %%
pokemon = 'https://pokeapi.co/api/v2/pokemon/'

# %%
resp_pokemon = requests.get(pokemon)

# %%
resp_pokemon
# Out:
# <Response [200]>

# %%
data2 = resp_pokemon.json()

# %%
data2
# Out:
# {'count': 1302,
#  'next': 'https://pokeapi.co/api/v2/pokemon/?offset=20&limit=20',
#  'previous': None,
#  'results': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon/1/'},
#   {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/'},
#   {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/'},
#   {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#   {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#   {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#   {'name': 'squirtle', 'url': 'https://pokeapi.co/api/v2/pokemon/7/'},
#   {'name': 'wartortle', 'url': 'https://pokeapi.co/api/v2/pokemon/8/'},
#   {'name': 'blastoise', 'url': 'https://pokeapi.co/api/v2/pokemon/9/'},
#   {'name': 'caterpie', 'url': 'https://pokeapi.co/api/v2/pokemon/10/'},
#   {'name': 'metapod', 'url': 'https://pokeapi.co/api/v2/pokemon/11/'},
#   {'name': 'butterfree', 'url': 'https://pokeapi.co/api/v2/pokemon/12/'},
#   {'name': 'weedle', 'url': 'https://pokeapi.co/api/v2/pokemon/13/'},
#   {'name': 'kakuna', 'url': 'https://pokeapi.co/api/v2/pokemon/14/'},
#   {'name': 'beedrill', 'url': 'https://pokeapi.co/api/v2/pokemon/15/'},
#   {'name': 'pidgey', 'url': 'https://pokeapi.co/api/v2/pokemon/16/'},
#   {'name': 'pidgeotto', 'url': 'https://pokeapi.co/api/v2/pokemon/17/'},
#   {'name': 'pidgeot', 'url': 'https://pokeapi.co/api/v2/pokemon/18/'},
#   {'name': 'rattata', 'url': 'https://pokeapi.co/api/v2/pokemon/19/'},
#   {'name': 'raticate', 'url': 'https://pokeapi.co/api/v2/pokemon/20/'}]}

# %%
data2['results']
# Out:
# [{'name': 'bulbasaur', 'url': 'https://pokeapi.co/api/v2/pokemon/1/'},
#  {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/'},
#  {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/'},
#  {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#  {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#  {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#  {'name': 'squirtle', 'url': 'https://pokeapi.co/api/v2/pokemon/7/'},
#  {'name': 'wartortle', 'url': 'https://pokeapi.co/api/v2/pokemon/8/'},
#  {'name': 'blastoise', 'url': 'https://pokeapi.co/api/v2/pokemon/9/'},
#  {'name': 'caterpie', 'url': 'https://pokeapi.co/api/v2/pokemon/10/'},
#  {'name': 'metapod', 'url': 'https://pokeapi.co/api/v2/pokemon/11/'},
#  {'name': 'butterfree', 'url': 'https://pokeapi.co/api/v2/pokemon/12/'},
#  {'name': 'weedle', 'url': 'https://pokeapi.co/api/v2/pokemon/13/'},
#  {'name': 'kakuna', 'url': 'https://pokeapi.co/api/v2/pokemon/14/'},
#  {'name': 'beedrill', 'url': 'https://pokeapi.co/api/v2/pokemon/15/'},
#  {'name': 'pidgey', 'url': 'https://pokeapi.co/api/v2/pokemon/16/'},
#  {'name': 'pidgeotto', 'url': 'https://pokeapi.co/api/v2/pokemon/17/'},
#  {'name': 'pidgeot', 'url': 'https://pokeapi.co/api/v2/pokemon/18/'},
#  {'name': 'rattata', 'url': 'https://pokeapi.co/api/v2/pokemon/19/'},
#  {'name': 'raticate', 'url': 'https://pokeapi.co/api/v2/pokemon/20/'}]

# %%
data2['results'][3]
# Out:
# {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'}

# %%
data2['results'][3]['url']
# Out:
# 'https://pokeapi.co/api/v2/pokemon/4/'

# %% [markdown]
# Interagindo com bancos de dados

# %%
import sqlite3

# %%
# Cria a tabela
query = """
CREATE TABLE test (
  a VARCHAR(20),
  b VARCHAR(20),
  c REAL,
  d INTEGER
);"""

# %%
con = sqlite3.connect('mydata.sqlite')

# %%
con.execute(query)

# %%
con.commit()

# %%
# Insere dados na tabela
data = [('Atlanta', 'Georgia', 1.25, 6),
        ('Tallahassee','Florida', 2.6, 3),
        ('Sacramento', 'California',1.7, 5)]

# %%
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"

# %%
con.executemany(stmt, data)

# %%
con.commit()

# %%
cursor = con.execute('SELECT * FROM test')

# %%
rows = cursor.fetchall()

# %%
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('sacramento', 'California', 1.7, 5),
#  ('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
# Out:
# (('a', None, None, None, None, None, None),
#  ('b', None, None, None, None, None, None),
#  ('c', None, None, None, None, None, None),
#  ('d', None, None, None, None, None, None))

# %%
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   sacramento  California  1.70  5
# 3      Atlanta     Georgia  1.25  6
# 4  Tallahassee     Florida  2.60  3
# 5   Sacramento  California  1.70  5

# %%
import sqlalchemy as sqla

# %%
db = sqla.create_engine('sqlite:///mydata.sqlite')

# %%
pd.read_sql('SELECT * FROM test', db)

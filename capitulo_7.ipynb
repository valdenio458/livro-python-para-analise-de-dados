# %% [markdown]
# <a href="https://colab.research.google.com/github/valdenio458/livro-python-para-analise-de-dados/blob/main/capitulo_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Limpeza e preparação dos dados

# %% [markdown]
# ### 7.1 Tratando dados ausentes

# %%
string_data = pd.Series(['aardvark', 'artichoke', np.nan, 'avocado'])

# %%
string_data
# Out:
# 0     aardvark
# 1    artichoke
# 2          NaN
# 3      avocado
# dtype: object

# %%
string_data.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# Filtrando dados ausentes

# %%
from numpy import nan as NA

# %%
data = pd.Series([1, NA, 3.5, NA, 7])

# %%
data
# Out:
# 0    1.0
# 1    NaN
# 2    3.5
# 3    NaN
# 4    7.0
# dtype: float64

# %%
data.dropna()
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
# dropna() é equivalente a notnull()
data[data.notnull()]
# Out:
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., NA, NA],
                    [NA, NA, NA], [NA, 6.5, 3.]])

# %%
cleaned = data.dropna()

# %%
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
cleaned
# Out:
#      0    1    2
# 0  1.0  6.5  3.0

# %%
# Passar how='all' descartará apenas as linhas que contenham somente NAs:
data.dropna(how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
# cria uma coluna só com NAs
data[4] = NA

# %%
data
# Out:
#      0    1    2   4
# 0  1.0  6.5  3.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  3.0 NaN

# %%
# Para descartar colunas que só contenham NAs, passe axis=1, how='all
data.dropna(axis=1, how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %% [markdown]
# Preenchendo dados ausentes

# %%
df = pd.DataFrame(np.random.randn(7, 3))

# %%
df
# Out:
#           0         1         2
# 0  1.405059  1.901578 -1.285117
# 1 -1.002033  0.129158  0.635939
# 2 -0.690708 -2.190584  0.881995
# 3 -1.643640 -0.416289 -0.271256
# 4 -0.770683  0.999375  0.067851
# 5 -1.462903 -1.158363  0.682608
# 6 -0.185924 -0.021092 -0.507284

# %%
df.iloc[:4, 1] = NA

# %%
df.iloc[:2, 2] = NA

# %%
df
# Out:
#           0         1         2
# 0  1.405059       NaN       NaN
# 1 -1.002033       NaN       NaN
# 2 -0.690708       NaN  0.881995
# 3 -1.643640       NaN -0.271256
# 4 -0.770683  0.999375  0.067851
# 5 -1.462903 -1.158363  0.682608
# 6 -0.185924 -0.021092 -0.507284

# %%
# Chamar fillna com uma constante como argumento, substitui valores ausentes por esse valor
df.fillna(0)
# Out:
#           0         1         2
# 0  1.405059  0.000000  0.000000
# 1 -1.002033  0.000000  0.000000
# 2 -0.690708  0.000000  0.881995
# 3 -1.643640  0.000000 -0.271256
# 4 -0.770683  0.999375  0.067851
# 5 -1.462903 -1.158363  0.682608
# 6 -0.185924 -0.021092 -0.507284

# %%
# Ao chamar fillna com um dicionário, podemos usar um valor de preenchimento
# diferente para cada coluna
df.fillna({1: 0.5, 2: 2.})
# Out:
#     0         1         2
# 0 NaN  0.500000  2.000000
# 1 NaN  0.500000  2.000000
# 2 NaN  0.500000  1.100587
# 3 NaN  0.500000 -0.931528
# 4 NaN  0.476890  0.395294
# 5 NaN -0.822494  0.914303
# 6 NaN  0.679759  0.796003

# %%
# fillna devolve um novo objeto. Para alterar o objeto existente use o argumento
# inplace
df.fillna(5., inplace=True)

# %%
df
# Out:
#      0         1         2
# 0  5.0  5.000000  5.000000
# 1  5.0  5.000000  5.000000
# 2  5.0  5.000000  1.100587
# 3  5.0  5.000000 -0.931528
# 4  5.0  0.476890  0.395294
# 5  5.0 -0.822494  0.914303
# 6  5.0  0.679759  0.796003

# %% [markdown]
# ### 7.2 Transformação de dados

# %% [markdown]
# Removendo duplicatas

# %%
data = pd.DataFrame({'k1' : ['one', 'two'] * 3 + ['two'],
                     'k2': [1, 1, 2, 3, 3, 4, 4]})

# %%
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
# O método 'duplicated' devolve uma Series boolena informando se cada linha
# é uma duplicata ou não
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
# 'drop_duplicates' devolve um DataFrame com dados em que o array 'duplicated' é False
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %%
# Adicionando uma nova coluna ao DataFrame
data['v1'] = range(7)
data
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
# Filtrando as duplicatas somente com base na coluna 'k1'

# %%
data.drop_duplicates('k1')
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1

# %%
# 'duplicated' e 'drop_duplicates', por padrão, mantém a primeira combinação
# de valores observada. Passar keep='last' devolverá a última
data.drop_duplicates(['k1','k2'], keep='last')
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 6  two   4   6

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# Transformando dados usando uma função ou um mapeamento

# %%
data = pd.DataFrame({'food' : ['bacon', 'pulled pork', 'bacon',
                               'Pastrami', 'corned beef', 'Bacon',
                               'pastrami', 'honey ham', 'nova lox'],
                     'ounces' : [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})

# %%
data
# Out:
#           food  ounces
# 0        bacon     4.0
# 1  pulled pork     3.0
# 2        bacon    12.0
# 3     Pastrami     6.0
# 4  corned beef     7.5
# 5        Bacon     8.0
# 6     pastrami     3.0
# 7    honey ham     5.0
# 8     nova lox     6.0

# %%
meat_to_animal = {
    'bacon' : 'pig',
    'pulled pork' : 'pig',
    'pastrami' : 'cow',
    'corned beef' : 'cow',
    'honey ham' : 'pig',
    'nova lox' : 'salmon'
}

# %%
# Converter todos os valores da coluna 'food' para minúsculas
lowercased = data['food'].str.lower()

# %%
lowercased
# Out:
# 0          bacon
# 1    pulled pork
# 2          bacon
# 3       pastrami
# 4    corned beef
# 5          bacon
# 6       pastrami
# 7      honey ham
# 8       nova lox
# Name: food, dtype: object

# %%
# Cria uma nova coluna 'animal' e usa a função 'map' para preenchê-la
data['animal'] = lowercased.map(meat_to_animal)

# %%
data
# Out:
#           food  ounces  animal
# 0        bacon     4.0     pig
# 1  pulled pork     3.0     pig
# 2        bacon    12.0     pig
# 3     Pastrami     6.0     cow
# 4  corned beef     7.5     cow
# 5        Bacon     8.0     pig
# 6     pastrami     3.0     cow
# 7    honey ham     5.0     pig
# 8     nova lox     6.0  salmon

# %% [markdown]
# Substituindo valores

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])

# %%
data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
# Para substituir diversos valores de uma só vez, passe uma lista e, em seguida,
# o valor para substituição
data.replace([-999., -1000.], np.nan)
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    NaN
# 5    3.0
# dtype: float64

# %%
# Para usar um substituto diferente para cada valor, passe uma lista deles
data.replace([-999, -1000], [np.nan, 0])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %%
# O argumento especificado também pode ser um dicionário
data.replace({-999 : np.nan, -1000: 0})
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %% [markdown]
# Renomeando os índices dos eixos

# %%
data = pd.DataFrame(np.arange(12).reshape((3,4)),
                                          index=['Ohio','Colorado','New York'],
                                          columns=['one', 'two', 'three','four'])

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
# Como em uma Series, os índices de um eixo têm um método map
transform = lambda x: x[:4].upper()

# %%
data.index.map(transform)
# Out:
# Index(['OHIO', 'COLO', 'NEW '], dtype='object')

# %%
# Fazendo uma atribuição para index, modificando o DataFrame in-place
data.index = data.index.map(transform)

# %%
data
# Out:
#       one  two  three  four
# OHIO    0    1      2     3
# COLO    4    5      6     7
# NEW     8    9     10    11

# %%
# Criando uma versão transformada de um conjunto de dados sem modificar
# os dados originais, usando o método rename
data.rename(index=str.title, columns=str.upper)
# Out:
#       ONE  TWO  THREE  FOUR
# Ohio    0    1      2     3
# Colo    4    5      6     7
# New     8    9     10    11

# %%
# rename pode ser usado em conjunto com um objeto do tipo dicionário
# fornecendo novos valores para um subconjunto dos rótulos de um eixo
data.rename(index={'OHIO': 'INDIANA'},
            columns={'three': 'peekaboo'})
# Out:
#          one  two  peekaboo  four
# INDIANA    0    1         2     3
# COLO       4    5         6     7
# NEW        8    9        10    11

# %% [markdown]
# Detectando e filtrando valores discrepantes (outliers)

# %%
data = pd.DataFrame(np.random.randn(1000, 4))

# %%
data.describe()
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.007612     0.013220    -0.010623    -0.024914
# std       1.001749     0.970746     1.044913     1.016675
# min      -3.723092    -2.987946    -3.479497    -2.898841
# 25%      -0.647882    -0.644074    -0.704243    -0.721488
# 50%       0.022780    -0.025474    -0.002598    -0.032571
# 75%       0.684406     0.641173     0.683748     0.639775
# max       3.011292     3.352543     3.633696     3.085490

# %%
col = data[2]

# %%
# Encontrar valores que excedam 3 em vazlor absoluto em uma das colunas
col[np.abs(col) > 3]
# Out:
# 112   -3.479497
# 429    3.102885
# 714    3.633696
# 819    3.293477
# Name: 2, dtype: float64

# %% [markdown]
# ### 7.3 Manipulação de strings

# %% [markdown]
# Métodos de objetos string

# %%
# Uma string separad por vírgulas pode ser dividida em partes usando 'split'
val = 'a, b,  guido'

# %%
val.split(',')
# Out:
# ['a', ' b', '  guido']

# %%
# Com frequência, 'split' é usado em conjunto com 'strip' para remover
# espaços em branco (incluindo quebras de linha)
pieces = [x.strip() for x in val.split(',')]

# %%
pieces
# Out:
# ['a', 'b', 'guido']

# %%
# Métodos de localização de substrings
'guido' in val
# Out:
# True

# %%
# Métodos de localização de substrings
val.index(',')
# Out:
# 1

# %%
# Métodos de localização de substrings
val.find(':')
# Out:
# -1

# %%
# A diferença entre 'find' e 'index' é que 'index' lança uma exceção caso
# a substring não seja encontrada
val.index(':')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-24ffeabaeb9e> in <cell line: 3>()
#       1 # A diferença entre 'find' e 'index' é que 'index' lança uma exceção caso
#       2 # a string não seja encontrada
# ----> 3 val.index(':')
#
# ValueError: substring not found

# %%
# Devolve o número de de ocorrências de uma substring em particular
val.count(',')
# Out:
# 2
